# %%
crates = [10,5,1,10,3,8,5,2,2]

# %%
crates = list(set(crates))
crates.sort(reverse=True)
crates
# Out:
# [10, 8, 5, 3, 2, 1]

# %%
total = sum(crates)
total
# Out:
# 29

# %%
def calc_crates(crates: list[int]) -> int:
    crates = list(set(crates))
    crates.sort(reverse=True)
    return sum(crates)

# %%
with open("everybody_codes_e2025_q03_p1.txt", "r") as f:
    line = f.readline()  # Read the line
    numbers = [int(x) for x in line.split(",")]

# %%
calc_crates(numbers)
# Out:
# 2551
