# %%
with open("everybody_codes_e2025_q01_p3.txt", "r") as file:
    lines= file.readlines()


names = lines[0].split(',')
instructions = lines[2].split(',')

# %%
def move(current_position:int, instruction: str):
        parsed = parse_instruction(instruction)
        if parsed is None:
            print("Invalid instruction:", instruction)
            return current_position
        direction, step_amount = parsed
        if direction == "L":
            current_position = (current_position - step_amount) % len(names)
            return current_position
        if direction == "R":
            current_position = (current_position + step_amount) % len(names)
            return current_position
        else:
            print("Error")
            return current_position


def parse_instruction(instruction: str):
    direction = instruction[0]
    amount = int(instruction[1:])
    return direction, amount

# %%
for inst in instructions:
    current_position = 0
    current_position = move(current_position, inst)
    name_1 = names[0]
    name_2 = names[current_position]
    names[0] = name_2
    names[current_position] = name_1

print(names[0])
# Out:
# Ildkael
